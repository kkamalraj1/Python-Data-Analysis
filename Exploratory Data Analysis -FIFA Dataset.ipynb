# %% [markdown]
# ## Import Data
# ## Plot Age Density of players
# ## Find out Top 10 players based on their ratings
# ## Dream 11 players

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
df=pd.read_csv("FullData.csv")

# %%
df.head(3)
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
#
#       ...      Long_Shots Curve Freekick_Accuracy Penalties  Volleys  \
# 0     ...              90    81                76        85       88
# 1     ...              88    89                90        74       85
# 2     ...              77    79                84        81       83
#
#   GK_Positioning GK_Diving  GK_Kicking  GK_Handling  GK_Reflexes
# ...

# %%
df.describe()
# Out:
#        National_Kit      Club_Kit  Contract_Expiry        Rating  \
# count   1075.000000  17587.000000     17587.000000  17588.000000
# mean      12.219535     21.294536      2018.899414     66.166193
# std        6.933187     19.163741         1.698787      7.083012
# min        1.000000      1.000000      2017.000000     45.000000
# 25%        6.000000      9.000000      2017.000000     62.000000
# 50%       12.000000     18.000000      2019.000000     66.000000
# 75%       18.000000     27.000000      2020.000000     71.000000
# max       36.000000     99.000000      2023.000000     94.000000
#
#                 Age     Weak_foot   Skill_Moves  Ball_Control     Dribbling  \
# count  17588.000000  17588.000000  17588.000000  17588.000000  17588.000000
# mean      25.460314      2.934103      2.303161     57.972766     54.802877
# std        4.680217      0.655927      0.746156     16.834779     18.913857
# ...

# %%
df.isnull().any()
# Out:
# Name                  False
# Nationality           False
# National_Position      True
# National_Kit           True
# Club                  False
# Club_Position          True
# Club_Kit               True
# Club_Joining           True
# Contract_Expiry        True
# Rating                False
# Height                False
# Weight                False
# Preffered_Foot        False
# Birth_Date            False
# Age                   False
# Preffered_Position    False
# Work_Rate             False
# Weak_foot             False
# Skill_Moves           False
# Ball_Control          False
# Dribbling             False
# Marking               False
# Sliding_Tackle        False
# Standing_Tackle       False
# Aggression            False
# Reactions             False
# Attacking_Position    False
# Interceptions         False
# Vision                False
# Composure             False
# Crossing              False
# Short_Pass            False
# Long_Pass             False
# ...

# %%
df.drop(["National_Position","National_Kit"],axis=1,inplace=True)

# %%
df.head(3)
# Out:
#                 Name Nationality          Club Club_Position  Club_Kit  \
# 0  Cristiano Ronaldo    Portugal   Real Madrid            LW       7.0
# 1       Lionel Messi   Argentina  FC Barcelona            RW      10.0
# 2             Neymar      Brazil  FC Barcelona            LW      11.0
#
#   Club_Joining  Contract_Expiry  Rating  Height Weight     ...       \
# 0   07/01/2009           2021.0      94  185 cm  80 kg     ...
# 1   07/01/2004           2018.0      93  170 cm  72 kg     ...
# 2   07/01/2013           2021.0      92  174 cm  68 kg     ...
#
#   Long_Shots Curve  Freekick_Accuracy Penalties Volleys  GK_Positioning  \
# 0         90    81                 76        85      88              14
# 1         88    89                 90        74      85              14
# 2         77    79                 84        81      83              15
#
#    GK_Diving  GK_Kicking  GK_Handling  GK_Reflexes
# 0          7          15           11           11
# ...

# %% [markdown]
# ### Age density of players

# %%
df.Age.plot(kind="Density")
plt.xlabel("Age")
plt.show()

# %% [markdown]
# ### Identify Top 10 Players by their Rating

# %%
df.sort_values(['Rating','Name'],ascending=False).head(10)
# Out:
#                  Name Nationality            Club Club_Position  Club_Kit  \
# 0   Cristiano Ronaldo    Portugal     Real Madrid            LW       7.0
# 1        Lionel Messi   Argentina    FC Barcelona            RW      10.0
# 2              Neymar      Brazil    FC Barcelona            LW      11.0
# 4        Manuel Neuer     Germany       FC Bayern            GK       1.0
# 3         Luis Suárez     Uruguay    FC Barcelona            ST       9.0
# 8  Zlatan Ibrahimović      Sweden  Manchester Utd            ST       9.0
# 6  Robert Lewandowski      Poland       FC Bayern            ST       9.0
# 7         Gareth Bale       Wales     Real Madrid            RW      11.0
# 5              De Gea       Spain  Manchester Utd            GK       1.0
# 9    Thibaut Courtois     Belgium         Chelsea            GK      13.0
#
#   Club_Joining  Contract_Expiry  Rating  Height Weight     ...       \
# 0   07/01/2009           2021.0      94  185 cm  80 kg     ...
# ...

# %% [markdown]
# ### Finding the best goal keeper

# %% [markdown]
# #### Characteristic of Goal Keeper
# #### Shot Stopper
# #### Sweeper

# %%
#weights
a = 0.5
b = 1
c= 2
d = 3
 
#GoalKeeping Characterstics
df['gk_Shot_Stopper'] = (b*df.Reactions + b*df.Composure + a*df.Speed + a*df.Strength + c*df.Jumping + b*df.GK_Positioning + c*df.GK_Diving + d*df.GK_Reflexes + b*df.GK_Handling)/(2*a + 4*b + 2*c + 1*d)
df['gk_Sweeper'] = (b*df.Reactions + b*df.Composure + b*df.Speed + a*df.Short_Pass + a*df.Long_Pass + b*df.Jumping + b*df.GK_Positioning + b*df.GK_Diving + d*df.GK_Reflexes + b*df.GK_Handling + d*df.GK_Kicking + c*df.Vision)/(2*a + 4*b + 3*c + 2*d)

# %%
plt.figure(figsize=(15,6))
df1 = df.sort_values(['gk_Shot_Stopper'],ascending=False).head(5)
x1=np.array(list(df1['Name']))
y1=np.array(list(df1['gk_Shot_Stopper']))
plt.bar(x1,y1,color='orange')
plt.xlabel('Player Name')
plt.ylabel('Shot Stopper Score')
plt.title("Top 5 Goal Keeper - Shot Stopper")
# Out:
# Text(0.5, 1.0, 'Top 5 Goal Keeper - Shot Stopper')

# %%
plt.figure(figsize=(15,6))
df2 = df.sort_values(['gk_Sweeper'],ascending=False).head(5)
x2=np.array(list(df2['Name']))
y2=np.array(list(df2['gk_Sweeper']))
plt.bar(x2,y2,color='blue')
plt.xlabel('Player Name')
plt.ylabel('Sweeper')
plt.title("Top 5 Goal Keeper - Sweeper")
# Out:
# Text(0.5, 1.0, 'Top 5 Goal Keeper - Sweeper')

# %%
img = mpimg.imread('Manuel Neuer.png')
plt.title('Best Goal Keeper')
plt.xlabel('Manuel Neuer')
plt.imshow(img)

# %% [markdown]
# ### Finding the Best Defenders

# %% [markdown]
# ##### Center Backs: We will need two center backs. One who plays Left Center Back (LCB) and the other who plays Right Center Back (RCB)
# ##### Wing Backs: We will need two wing backs. One who plays Left Wing Back (LWB) and the other who plays Right Wing Back (RWB)

# %%
df['df_centre_backs'] = ( d*df.Reactions + c*df.Interceptions + d*df.Sliding_Tackle + d*df.Standing_Tackle + b*df.Vision+ b*df.Composure + b*df.Crossing +a*df.Short_Pass + b*df.Long_Pass+ c*df.Acceleration + b*df.Speed
+ d*df.Stamina + d*df.Jumping + d*df.Heading + b*df.Long_Shots + d*df.Marking + c*df.Aggression)/(6*b + 3*c + 7*d)
df['df_wb_Wing_Backs'] = (b*df.Ball_Control + a*df.Dribbling + a*df.Marking + d*df.Sliding_Tackle + d*df.Standing_Tackle + a*df.Attacking_Position + c*df.Vision + c*df.Crossing + b*df.Short_Pass + c*df.Long_Pass + d*df.Acceleration +d*df.Speed + c*df.Stamina + a*df.Finishing)/(4*a + 2*b + 4*c + 4*d)

# %% [markdown]
# #### Left Central Defender

# %%
plt.figure(figsize=(15,6))
df3 = df[(df['Club_Position'] == 'LCB')].sort_values('df_centre_backs', ascending=False).head(5)
x3 = np.array(list(df3['Name']))
y3 = np.array(list(df3['df_centre_backs']))
plt.bar(x3, y3)
plt.xlabel("Player Name")
plt.ylabel("LCB Score")
plt.title("Left Central Defender")
# Out:
# Text(0.5, 1.0, 'Left Central Defender')

# %%
img = mpimg.imread('Sergio Ramos.png')
plt.title('Best Left Central Defender')
plt.xlabel('Sergio Ramos')
plt.imshow(img)

# %% [markdown]
# #### Right Central Defender

# %%
plt.figure(figsize=(15,6))
df4 = df[(df['Club_Position'] == 'RCB')].sort_values('df_centre_backs', ascending=False).head(5)
x4 = np.array(list(df4['Name']))
y4 = np.array(list(df4['df_centre_backs']))
plt.bar(x4, y4)
plt.xlabel("Player Name")
plt.ylabel("RCB Score")
plt.title("Right Central Defender")
# Out:
# Text(0.5, 1.0, 'Right Central Defender')

# %%
img = mpimg.imread('Azpilicueta.png')
plt.title('Best Right Central Defender')
plt.xlabel('Azpilicueta')
plt.imshow(img)

# %% [markdown]
# #### Left Wing Back

# %%
plt.figure(figsize=(15,6))
df5 = df[(df['Club_Position'] == 'LWB') | (df['Club_Position'] == 'LB')].sort_values('df_wb_Wing_Backs', ascending=False)[:5]
x5 = np.array(list(df5['Name']))
y5 = np.array(list(df5['df_wb_Wing_Backs']))
plt.bar(x5, y5)
plt.xlabel("Player Name")
plt.ylabel("Left Back Score")
plt.title("Left Wing Back")
# Out:
# Text(0.5, 1.0, 'Left Wing Back')

# %%
img = mpimg.imread('David Alaba.png')
plt.title('Best Left Wing Back')
plt.xlabel('David Alaba')
plt.imshow(img)

# %% [markdown]
# #### Right Wing Back

# %%
plt.figure(figsize=(15,6))
df6 = df[(df['Club_Position'] == 'RWB') | (df['Club_Position'] == 'RB')].sort_values('df_wb_Wing_Backs', ascending=False)[:5]
x6 = np.array(list(df6['Name']))
y6 = np.array(list(df6['df_wb_Wing_Backs']))
plt.bar(x6, y6)
plt.xlabel("Player Name")
plt.ylabel("Right Back Score")
plt.title("Right Wing Back")
# Out:
# Text(0.5, 1.0, 'Right Wing Back')

# %%
img = mpimg.imread('Kyle Walker.png')
plt.title('Best Right Wing Back')
plt.xlabel('Kyle Walker')
plt.imshow(img)

# %% [markdown]
# #### Finding the Best Mid-Fielders

# %%
df['mf_playmaker'] = (d*df.Ball_Control + d*df.Dribbling + a*df.Marking + d*df.Reactions + d*df.Vision + c*df.Attacking_Position + c*df.Crossing + d*df.Short_Pass + c*df.Long_Pass + c*df.Curve + b*df.Long_Shots + c*df.Freekick_Accuracy)/(1*a + 1*b + 4*c + 4*d)
df['mf_beast'] = (d*df.Agility + c*df.Balance + b*df.Jumping + c*df.Strength + d*df.Stamina + a*df.Speed + c*df.Acceleration + d*df.Short_Pass + c*df.Aggression + d*df.Reactions + b*df.Marking + b*df.Standing_Tackle + b*df.Sliding_Tackle + b*df.Interceptions)/(1*a + 5*b + 4*c + 4*d)
df['mf_controller'] = (b*df.Weak_foot + d*df.Ball_Control + a*df.Dribbling + a*df.Marking + a*df.Reactions + c*df.Vision + c*df.Composure + d*df.Short_Pass + d*df.Long_Pass)/(2*c + 3*d + 4*a)

# %% [markdown]
# #### Playmaker

# %%
plt.figure(figsize=(15,6))
 
df7 = df[(df['Club_Position'] == 'CAM') | (df['Club_Position'] == 'LAM') | (df['Club_Position'] == 'RAM')].sort_values('mf_playmaker', ascending=False)[:5]
x7 = np.array(list(df7['Name']))
y7 = np.array(list(df7['mf_playmaker']))
plt.bar(x7, y7)
plt.xlabel("Player Name")
plt.ylabel("Playmaker Score")
plt.title("Playmaker")
# Out:
# Text(0.5, 1.0, 'Playmaker')

# %%
img = mpimg.imread('Mesut zil.png')
plt.title('Best Playmaker')
plt.xlabel('Mesut Ozil')
plt.imshow(img)

# %%
plt.figure(figsize=(15,6))
 
df8 = df[(df['Club_Position'] == 'CAM') | (df['Club_Position'] == 'RCM') | (df['Club_Position'] == 'RM')].sort_values('mf_beast', ascending=False)[:5]
x8 = np.array(list(df8['Name']))
y8 = np.array(list(df8['mf_beast']))
plt.bar(x8, y8)
plt.xlabel("Player Name")
plt.ylabel("Beast Score")
plt.title("Beast")
# Out:
# Text(0.5, 1.0, 'Beast')

# %%
img = mpimg.imread('NGolo Kant.png')
plt.title('Best Beast')
plt.xlabel('NGolo Kante')
plt.imshow(img)

# %%
plt.figure(figsize=(15,6))
 
df9 = df[(df['Club_Position'] == 'CAM') | (df['Club_Position'] == 'LCM') | (df['Club_Position'] == 'LM')].sort_values('mf_controller', ascending=False)[:5]
x9 = np.array(list(df9['Name']))
y9 = np.array(list(df9['mf_controller']))
plt.bar(x9, y9)
plt.xlabel("Player Name")
plt.ylabel("Controller Score")
plt.title("Controller")
# Out:
# Text(0.5, 1.0, 'Controller')

# %%
img = mpimg.imread('Iniesta.png')
plt.title('Best Controller')
plt.xlabel('Iniesta')
plt.imshow(img)

# %% [markdown]
# #### Finding the best strikers

# %%
df['att_left_wing'] = (c*df.Weak_foot + c*df.Ball_Control + c*df.Dribbling + c*df.Speed + d*df.Acceleration + b*df.Vision + c*df.Crossing + b*df.Short_Pass + b*df.Long_Pass + b*df.Aggression + b*df.Agility + a*df.Curve + c*df.Long_Shots + b*df.Freekick_Accuracy + d*df.Finishing)/(a + 6*b + 6*c + 2*d)
df['att_right_wing'] = (c*df.Weak_foot + c*df.Ball_Control + c*df.Dribbling + c*df.Speed + d*df.Acceleration + b*df.Vision + c*df.Crossing + b*df.Short_Pass + b*df.Long_Pass + b*df.Aggression + b*df.Agility + a*df.Curve + c*df.Long_Shots + b*df.Freekick_Accuracy + d*df.Finishing)/(a + 6*b + 6*c + 2*d)
df['att_striker'] = (b*df.Weak_foot + b*df.Ball_Control + a*df.Vision + b*df.Aggression + b*df.Agility + a*df.Curve + a*df.Long_Shots + d*df.Balance + d*df.Finishing + d*df.Heading + c*df.Jumping + c*df.Dribbling)/(3*a + 4*b + 2*c + 3*d)

# %%
plt.figure(figsize=(15,6))
df10 = df[(df['Club_Position'] == 'LW') | (df['Club_Position'] == 'LM') | (df['Club_Position'] == 'LS')].sort_values('att_left_wing', ascending=False)[:5]
x10 = np.array(list(df10['Name']))
y10 = np.array(list(df10['att_left_wing']))
plt.bar(x10, y10)
plt.xlabel("Player Name")
plt.ylabel("Left Wing")
plt.title("Left Wing Striker")
# Out:
# Text(0.5, 1.0, 'Left Wing Striker')

# %%
img = mpimg.imread('Cristiano Ronaldo.png')
plt.title('Best Left Wing Striker')
plt.xlabel('Cristiano Ronaldo')
plt.imshow(img)

# %%
plt.figure(figsize=(15,6))
df11 = df[(df['Club_Position'] == 'RW') | (df['Club_Position'] == 'RM') | (df['Club_Position'] == 'RS')].sort_values('att_right_wing', ascending=False)[:5]
x11 = np.array(list(df11['Name']))
y11 = np.array(list(df11['att_right_wing']))
plt.bar(x11, y11)
plt.xlabel("Player Name")
plt.ylabel("Right Wing")
plt.title("Right Wing Striker")
# Out:
# Text(0.5, 1.0, 'Right Wing Striker')

# %%
img = mpimg.imread('Lionel Messi.png')
plt.title('Best Right Wing Striker')
plt.xlabel('Lionel Messi')
plt.imshow(img)

# %%
plt.figure(figsize=(15,6))
df12 = df[(df['Club_Position'] == 'ST') | (df['Club_Position'] == 'LS') | (df['Club_Position'] == 'RS') | (df['Club_Position'] =='CF')].sort_values('att_striker', ascending=False)[:5]
x12 = np.array(list(df12['Name']))
y12 = np.array(list(df12['att_striker']))
plt.bar(x12, y12)
plt.xlabel("Player Name")
plt.ylabel("Central Striker")
plt.title("Striker")
# Out:
# Text(0.5, 1.0, 'Striker')

# %%
img = mpimg.imread('Robert Lewandowski.png')
plt.title('Best Central Striker')
plt.xlabel('Robert Lewandowski')
plt.imshow(img)
